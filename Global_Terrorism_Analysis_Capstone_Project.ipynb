# %% [markdown]
# <a href="https://colab.research.google.com/github/Gauravgade3/Global-Terrorism-Analysis/blob/main/Global_Terrorism_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> The Global Terrorism Database (GTD) is an open-source database including information on terrorist attacks around the world from 1970 through 2017. The GTD includes systematic data on domestic as well as international terrorist incidents that have occurred during this time period and now includes more than 180,000 attacks. The database is maintained by researchers at the National Consortium for the Study of Terrorism and Responses to Terrorism (START), headquartered at the University of Maryland.</b>
#
# # <b> Explore and analyze the data to discover key findings pertaining to terrorist activities. </b>

# %% [markdown]
# # **Introduction**

# %% [markdown]
# **We have the database including more than 180,000 terrorist attacks around the world from 1970 to 2017. And we are going to find out relative information about this terrorist activities.**

# %%
# Mounting drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importing some necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Reading csv file
df=pd.read_csv('/content/drive/MyDrive/Almabetter/Copy of Global Terrorism Data.csv',encoding = "ISO-8859-1")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # **Exploring the dataset**

# %%
# Checking first 10 rows in dataset
df.head(10)
# Out:
#         eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0  197000000001   1970       7     2  ...        0         0       0      NaN
# 1  197000000002   1970       0     0  ...        1         1       1      NaN
# 2  197001000001   1970       1     0  ...       -9         1       1      NaN
# 3  197001000002   1970       1     0  ...       -9         1       1      NaN
# 4  197001000003   1970       1     0  ...       -9         1       1      NaN
# 5  197001010002   1970       1     1  ...       -9         0      -9      NaN
# 6  197001020001   1970       1     2  ...        0         0       0      NaN
# 7  197001020002   1970       1     2  ...       -9         0      -9      NaN
# 8  197001020003   1970       1     2  ...        0         0       0      NaN
# 9  197001030001   1970       1     3  ...        0         0       0      NaN
#
# [10 rows x 135 columns]

# %%
# Checking last 10 rows in dataset
df.tail(10)
# Out:
#              eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 181681  201712310016   2017      12    31  ...        0         0       0      NaN
# 181682  201712310017   2017      12    31  ...       -9         0      -9      NaN
# 181683  201712310018   2017      12    31  ...        0         0       0      NaN
# 181684  201712310019   2017      12    31  ...        0         0       0      NaN
# 181685  201712310020   2017      12    31  ...       -9         0      -9      NaN
# 181686  201712310022   2017      12    31  ...        0         0       0      NaN
# 181687  201712310029   2017      12    31  ...       -9         1       1      NaN
# 181688  201712310030   2017      12    31  ...        0         0       0      NaN
# 181689  201712310031   2017      12    31  ...       -9         0      -9      NaN
# 181690  201712310032   2017      12    31  ...       -9         0      -9      NaN
#
# [10 rows x 135 columns]

# %%
# Checking basic information of our dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
# Exploring descriptive statistical parameter
df.describe()
# Out:
#             eventid          iyear  ...       INT_MISC        INT_ANY
# count  1.816910e+05  181691.000000  ...  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997  ...       0.090010      -3.945952
# std    1.325957e+09      13.259430  ...       0.568457       4.691325
# min    1.970000e+11    1970.000000  ...      -9.000000      -9.000000
# 25%    1.991021e+11    1991.000000  ...       0.000000      -9.000000
# 50%    2.009022e+11    2009.000000  ...       0.000000       0.000000
# 75%    2.014081e+11    2014.000000  ...       0.000000       0.000000
# max    2.017123e+11    2017.000000  ...       1.000000       1.000000
#
# [8 rows x 77 columns]

# %% [markdown]
# # **Data Cleaning**

# %%
# checking the total number of null values in every column

df.isnull().sum().head(60)
# Out:
# eventid                  0
# iyear                    0
# imonth                   0
# iday                     0
# approxdate          172452
# extended                 0
# resolution          179471
# country                  0
# country_txt              0
# region                   0
# region_txt               0
# provstate              421
# city                   434
# latitude              4556
# longitude             4557
# specificity              6
# vicinity                 0
# location            126196
# summary              66129
# crit1                    0
# crit2                    0
# crit3                    0
# doubtterr                1
# alternative         152680
# alternative_txt     152680
# multiple                 1
# success                  0
# suicide                  0
# attacktype1              0
# attacktype1_txt          0
# attacktype2         175377
# attacktype2_txt     175377
# attacktype3         181263
# attacktype3_txt     181263
# ...

# %%
# Checking the shape of dataset
df.shape
# Out:
# (181691, 135)

# %%
# Copying the database
df1=df.copy()

# %%
# Verifying the shape of copied dataset
df1.shape
# Out:
# (181691, 135)

# %%
# Dropping the columns from top 60 columns containing large number of null values
df1.drop(['approxdate','resolution','alternative','alternative_txt','attacktype2','attacktype2_txt','attacktype3','attacktype3_txt','targtype2','targtype2_txt','targsubtype2','targsubtype2_txt','corp2','target2','natlty2','natlty2_txt','targtype3','targtype3_txt','targsubtype3','targsubtype3_txt','corp3','target3','natlty3','natlty3_txt','gsubname'],axis = 1, inplace=True)

# %%
# Checking the shape of dataset
df1.shape
# Out:
# (181691, 110)

# %%
# checking the total number of null values in every column

df.isnull().sum().tail(60)
# Out:
# claimmode2            181075
# claimmode2_txt        181075
# claim3                181373
# claimmode3            181558
# claimmode3_txt        181558
# compclaim             176852
# weaptype1                  0
# weaptype1_txt              0
# weapsubtype1           20768
# weapsubtype1_txt       20768
# weaptype2             168564
# weaptype2_txt         168564
# weapsubtype2          170149
# weapsubtype2_txt      170149
# weaptype3             179828
# weaptype3_txt         179828
# weapsubtype3          179998
# weapsubtype3_txt      179998
# weaptype4             181618
# weaptype4_txt         181618
# weapsubtype4          181621
# weapsubtype4_txt      181621
# weapdetail             67670
# nkill                  10313
# nkillus                64446
# nkillter               66958
# nwound                 16311
# nwoundus               64702
# nwoundte               69143
# property                   0
# propextent            117626
# propextent_txt        117626
# ...

# %%
# Dropping the columns from last 60 columns containing large number of null values

df1.drop(['claimmode2','claimmode2_txt','claim3','claimmode3','claimmode3_txt','compclaim','weapsubtype2','weapsubtype2_txt','weaptype3','weaptype3_txt','weapsubtype3','weapsubtype3_txt','weaptype4','weaptype4_txt','weapsubtype4','weapsubtype4_txt','nhours','ndays','divert','kidhijcountry','ransomamt','ransomamtus','ransompaid','ransompaidus','ransomnote','hostkidoutcome','hostkidoutcome_txt','nreleased'],axis=1,inplace=True)

# %%
# Checking the shape of dataset

df1.shape
# Out:
# (181691, 82)

# %%
# checking the total number of null values in every column

df1.isnull().sum().head(60)
# Out:
# eventid                  0
# iyear                    0
# imonth                   0
# iday                     0
# extended                 0
# country                  0
# country_txt              0
# region                   0
# region_txt               0
# provstate              421
# city                   434
# latitude              4556
# longitude             4557
# specificity              6
# vicinity                 0
# location            126196
# summary              66129
# crit1                    0
# crit2                    0
# crit3                    0
# doubtterr                1
# multiple                 1
# success                  0
# suicide                  0
# attacktype1              0
# attacktype1_txt          0
# targtype1                0
# targtype1_txt            0
# targsubtype1         10373
# targsubtype1_txt     10373
# corp1                42550
# target1                636
# natlty1               1559
# natlty1_txt           1559
# ...

# %%
# Dropping the columns from next top 60 columns containing large number of null values

df1.drop(['gname2','gsubname2','gname3','gsubname3','guncertain2','guncertain3','claim2','claimmode_txt','weaptype2_txt','addnotes','related','claimmode','weaptype2','nhostkidus'],axis=1,inplace=True)

# %%
# Checking the shape of dataset

df1.shape
# Out:
# (181691, 68)

# %%
# Dropping the columns from top 40 columns containing large number of null values

df1.isnull().sum().head(40)
# Out:
# eventid                  0
# iyear                    0
# imonth                   0
# iday                     0
# extended                 0
# country                  0
# country_txt              0
# region                   0
# region_txt               0
# provstate              421
# city                   434
# latitude              4556
# longitude             4557
# specificity              6
# vicinity                 0
# location            126196
# summary              66129
# crit1                    0
# crit2                    0
# crit3                    0
# doubtterr                1
# multiple                 1
# success                  0
# suicide                  0
# attacktype1              0
# attacktype1_txt          0
# targtype1                0
# targtype1_txt            0
# targsubtype1         10373
# targsubtype1_txt     10373
# corp1                42550
# target1                636
# natlty1               1559
# natlty1_txt           1559
# ...

# %%
# Dropping the columns from top 35 columns containing large number of null values

df1.isnull().sum().tail(35)
# Out:
# natlty1_txt           1559
# gname                    0
# motive              131130
# guncertain1            380
# individual               0
# nperps               71115
# nperpcap             69489
# claimed              66120
# weaptype1                0
# weaptype1_txt            0
# weapsubtype1         20768
# weapsubtype1_txt     20768
# weapdetail           67670
# nkill                10313
# nkillus              64446
# nkillter             66958
# nwound               16311
# nwoundus             64702
# nwoundte             69143
# property                 0
# propextent          117626
# propextent_txt      117626
# propvalue           142702
# propcomment         123732
# ishostkid              178
# nhostkid            168119
# ransom              104310
# scite1               66191
# scite2              104758
# scite3              138175
# dbsource                 0
# INT_LOG                  0
# INT_IDEO                 0
# INT_MISC                 0
# ...

# %%
# Checking basic information of our dataset

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 68 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   eventid           181691 non-null  int64
#  1   iyear             181691 non-null  int64
#  2   imonth            181691 non-null  int64
#  3   iday              181691 non-null  int64
#  4   extended          181691 non-null  int64
#  5   country           181691 non-null  int64
#  6   country_txt       181691 non-null  object
#  7   region            181691 non-null  int64
#  8   region_txt        181691 non-null  object
#  9   provstate         181270 non-null  object
#  10  city              181257 non-null  object
#  11  latitude          177135 non-null  float64
#  12  longitude         177134 non-null  float64
#  13  specificity       181685 non-null  float64
#  14  vicinity          181691 non-null  int64
#  15  location          55495 non-null   object
# ...

# %%
# Replacing the null values for object type

df1["provstate"].fillna("Not present",inplace = True)
df1["city"].fillna("Not present",inplace = True)
df1["location"].fillna("Not present",inplace = True)
df1["summary"].fillna("Not present",inplace = True)
df1["targsubtype1_txt"].fillna("Not present",inplace = True)
df1["corp1"].fillna("Not present",inplace = True)
df1["target1"].fillna("Not present",inplace = True)
df1["natlty1_txt"].fillna("Not present",inplace = True)
df1["motive"].fillna("Not present",inplace = True)
df1["weapsubtype1_txt"].fillna("Not present",inplace = True)
df1["weapdetail"].fillna("Not present",inplace = True)
df1["propextent_txt"].fillna("Not present",inplace = True)
df1["propcomment"].fillna("Not present",inplace = True)
df1["scite1"].fillna("Not present",inplace = True)
df1["scite2"].fillna("Not present",inplace = True)
df1["scite3"].fillna("Not present",inplace = True)

# %%
# Replacing the null values for int and float type

df1["latitude"].fillna(df["latitude"].mean(),inplace = True)
df1["longitude"].fillna(df["longitude"].mode(),inplace = True)
df1["doubtterr"].fillna(df["doubtterr"].mean(),inplace = True)
df1["multiple"].fillna(df["multiple"].mean(),inplace = True)
df1["targsubtype1"].fillna(df["targsubtype1"].mean(),inplace = True)
df1["natlty1"].fillna(df["natlty1"].mode(),inplace = True)
df1["guncertain1"].fillna(df["guncertain1"].mode(),inplace = True)
df1["nperps"].fillna(df["nperps"].mode(),inplace = True)
df1["nperpcap"].fillna(df["nperpcap"].mode(),inplace = True)
df1["claimed"].fillna(df["claimed"].mean(),inplace = True)
df1["weapsubtype1"].fillna(df["weapsubtype1"].mode(),inplace = True)
df1["nkill"].fillna(df["nkill"].mode(),inplace = True)
df1["nkillus"].fillna(df["nkillus"].mode(),inplace = True)
df1["nkillter"].fillna(df["nkillter"].mode(),inplace = True)
df1["nwound"].fillna(df["nwound"].mode(),inplace = True)
df1["nwoundus"].fillna(df["nwoundus"].mode(),inplace = True)
df1["nwoundte"].fillna(df["nwoundte"].mode(),inplace = True)
df1["propextent"].fillna(df["propextent"].mode(),inplace = True)
df1["propvalue"].fillna(df["propvalue"].mean(),inplace = True)
df1["nhostkid"].fillna(df["nhostkid"].mode(),inplace = True)
df1["ransom"].fillna(df["ransom"].mode(),inplace = True)

# %% [markdown]
# # **Exploratory Analysis and Visualization**

# %%
# Number of attacks in different years
number_attacks=df1['iyear'].value_counts().sort_index()
number_attacks
# Out:
# 1970      651
# 1971      471
# 1972      568
# 1973      473
# 1974      581
# 1975      740
# 1976      923
# 1977     1319
# 1978     1526
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 1983     2870
# 1984     3495
# 1985     2915
# 1986     2860
# 1987     3183
# 1988     3721
# 1989     4324
# 1990     3887
# 1991     4683
# 1992     5071
# 1994     3456
# 1995     3081
# 1996     3058
# 1997     3197
# 1998      934
# 1999     1395
# 2000     1814
# 2001     1906
# 2002     1333
# 2003     1278
# 2004     1166
# 2005     2017
# 2006     2758
# 2007     3242
# 2008     4805
# 2009     4721
# 2010     4826
# 2011     5076
# 2012     8522
# 2013    12036
# 2014    16903
# 2015    14965
# 2016    13587
# 2017    10900
# Name: iyear, dtype: int64

# %%
# Plotting total number of attacks through each year
number_attacks.plot(kind='bar',color='purple')
plt.rcParams['figure.figsize']=(20,7)
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.title('Total number of attacks',fontdict=font1)
plt.xlabel('Years',fontdict=font2)
plt.ylabel('Number of attacks',fontdict=font2)
plt.grid()

# %% [markdown]
# ### **From this graph, we have seen that 1971 is the year in which minimum (471) attacks got happened where the maximum attacks (16903) was done in 2014.**

# %%
# Number of attacks in different countries
number_attacks_country=df1['country_txt'].value_counts().sort_values(ascending=False).head(10)
number_attacks_country
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: country_txt, dtype: int64

# %%
# Plotting total number of attacks through different countries
number_attacks_country.plot(kind='barh',color='red')
plt.rcParams['figure.figsize']=(20,7)
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.title('Total number of attacks',fontdict=font1)
plt.xlabel('Country',fontdict=font2)
plt.ylabel('Number of attacks',fontdict=font2)
plt.grid()

# %% [markdown]
# ### **Here, maximum attacks (24636) was done in Iraq, it means Iraq is the first prefference of terrorist for attacks then Pakistan with 14368 attacks, Afganistan with12731 attacks, India with 11960 attacks, Colombia - 8306 attacks, these are the top 5 countries in terrorist attacks.**

# %%
# Finding most common type of attack
attack_type=df1['attacktype1_txt'].value_counts()
attack_type
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: attacktype1_txt, dtype: int64

# %%
# Plotting type of attacks
attack_type.plot(kind='line',color='magenta',marker='o',linewidth='3.5',ls='--',ms='15',mfc='orange', mec='cyan')
plt.rcParams['figure.figsize']=(20,7)
font1 = {'family':'serif','color':'green','size':20}
font2 = {'family':'serif','color':'purple','size':15}
plt.title('Total number of attacks Vs Types of attacks',fontdict=font1)
plt.xlabel('Types of attacks',fontdict=font2)
plt.ylabel('Number of attacks',fontdict=font2)
plt.grid()

# %% [markdown]
# ### **So, Bombing/Explosion was the most common type of attack (88255-Total attacks) then Armed Assault (42669) is second choice of terrorists where Hijacking is minimum kind of attack (659 in total).**

# %%
# Exploring targrt of terrorists
target_type=df1['targtype1_txt'].value_counts()
target_type
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# NGO                                 970
# Tourists                            440
# Maritime                            351
# Food or Water Supply                317
# Abortion Related                    263
# Other                               137
# Name: targtype1_txt, dtype: int64

# %%
# Visualising the target type of terrorists
target_type.plot(kind='bar',color='yellow',edgecolor='orange',linewidth=3.0)
plt.rcParams['figure.figsize']=(20,7)
font1 = {'family':'serif','color':'green','size':20}
font2 = {'family':'serif','color':'purple','size':15}
plt.title('Target Type Of Terrorists',fontdict=font1)
plt.xlabel('Types of target',fontdict=font2)
plt.ylabel('Number of attacks',fontdict=font2)
plt.grid(color='blue', linestyle = '--', linewidth = 0.2)

# %% [markdown]
# ### **This bar chart showing Private Citizens & Property was on the radar of the terrorists after that military was also second main focus for attacks and also police, government (general), business were in the list of terrorists.**
